# %%
from pypion.ReadData import ReadData
from pypion.argparse_command import InputValues
import yt

import numpy as np
import math
from astropy import units as u

import os
import glob
import re

# yt.set_log_level(30)

# %matplotlib notebook

# %%
class Plot_Functions:
    def __init__(self, path, image_dir, fluid_quantity, tolerance, plane):
        ########### Defining path to SILO files #######################
        self.data_path = path
        if os.path.exists(path):
            print(f"Chosen datapath: {path}")
        else:
            print(f"Directory does not exist: {path}")
            exit()
            
        ########### Base name of SILO files ############################
        self.filename=sorted(os.listdir(self.data_path))[2].replace('_level00_0000.00000000.silo','')
        print(self.filename)

        ########### Define desired fluid quantity ######################
        self.Quantity = fluid_quantity
        print(f"Fluid quantity: {self.Quantity}")
        self.Tolerance = tolerance
        print(f"vmin: {self.Tolerance[0]} \nvmax: {self.Tolerance[1]}")

        ########### If 3D, specify the coordinate plane ################
        surface_options = ['XY', 'XZ', 'YZ']
        self.Surface = plane
        if surface_options.count(self.Surface) > 0:
            print(f"Chosen surface: {self.Surface}")
        else:
            print(f"Invalid Surface Choice: {self.Surface}")
            exit()

        ########### Make snapshots of the simulation ###################
        self.evolution = self.make_snapshots(self.data_path, self.filename)

        ########### Find the dimensions of the simulation ##############
        self.find_dimensions()

    @staticmethod
    def make_snapshots(data_path, filename):
        ########## Cataloging silo files ###############################
        os.chdir(data_path)
        file_list = glob.glob('*.silo', recursive=True)
        level_list = []
        files = []

        for file in file_list:
            level = re.search('_level(.*)_', file)
            if level == None:
                pass
            else:
                level = level.group(1)
                if not level in level_list:
                    level_list.append(level)
        level_list.sort()

        ########## Categorizing data files into levels #################
        if len(level_list) == 1: 
            print('Simulation Info: Single level')
            catalog = []
            files = sorted(glob.glob(filename + '_0000.*.silo'))
            catalog.append(files)
        else:
            print(f'Simulation Info: {len(level_list)} levels')
            catalog = []
            for i in range(len(level_list)):
                files = sorted(glob.glob(f"{filename}_level{level_list[i]}_0000.*.silo"))
                catalog.append(files)
                
        # Bundle silo files of different levels of same time instant into a snapshot.
        evolution = np.array(catalog).T
        print(f"Shape of evolution array: {evolution.shape}")
        return evolution

    def find_dimensions(self):
        # Looking inside the simulation file for dimensions.
        info = ReadData(self.evolution[0])
        self.N_grids = info.ngrid()
        self.N_levels = info.nlevels()

        self.N_dims = 0
        for j in range(len(self.N_grids)):
            if self.N_grids[j] > 1: self.N_dims += 1
        print(f'Simulation Info: {self.N_dims}D System')
        #End of making snapshots ***************************************************

# %%
wr140 = Plot_Functions(path="/mnt/massive-stars/data/thomas_simulations/wr140-sims/covertex_start/orig_res/wr140-hydro-cool-n064/",
                    image_dir="/mnt/local/thomas/yt_images/",
                    fluid_quantity="density",
                    tolerance=[1e-30, 1e-20],
                    plane="XY")
# Out:
# Chosen datapath: /mnt/massive-stars/data/thomas_simulations/wr140-sims/covertex_start/orig_res/wr140-hydro-cool-n064/
# WR140_hydro_cool_d3l6n064
# Fluid quantity: density
# vmin: 1e-30
# vmax: 1e-20
# Chosen surface: XY
# Simulation Info: 6 levels
# Shape of evolution array: (423, 6)
# Simulation Info: 3D System

# %%
print(wr140.evolution[0])
# Out:
# ['WR140_hydro_cool_d3l6n064_level00_0000.00000000.silo'
#  'WR140_hydro_cool_d3l6n064_level01_0000.00000000.silo'
#  'WR140_hydro_cool_d3l6n064_level02_0000.00000000.silo'
#  'WR140_hydro_cool_d3l6n064_level03_0000.00000000.silo'
#  'WR140_hydro_cool_d3l6n064_level04_0000.00000000.silo'
#  'WR140_hydro_cool_d3l6n064_level05_0000.00000000.silo']

# %%
def get_ds(file) -> yt.data_objects.static_output.Dataset:
    data = ReadData(file)
    sim_time = data.sim_time()
    N_levels = data.nlevels()
    N_grids = data.ngrid()
    Dom_size = data.level_max() - data.level_min()

    data_den = data.get_3Darray("Density")['data']
    data_temp = data.get_3Darray("Temperature")['data']
    data_velx = data.get_3Darray("VelocityX")['data']
    data_vely = data.get_3Darray("VelocityY")['data']
    data_velz = data.get_3Darray("VelocityZ")['data']
    # data_ngmask = data.get_3Darray("NG_Mask")['data']

    grid_data = [dict(left_edge=[0.5-0.5**(n+1)]*len(N_grids), right_edge=[0.5+0.5**(n+1)]*len(N_grids), level=n, dimensions=N_grids) for n in range(N_levels)]

    i = 0
    for g in grid_data:
        g[("gas", "density")] = (data_den[i], "g/cm**3")
        g[("gas", "temperature")] = (data_temp[i], "K")
        g[("gas", "velocity_x")] = (data_velx[i], "cm/s")
        g[("gas", "velocity_y")] = (data_vely[i], "cm/s")
        g[("gas", "velocity_z")] = (data_velz[i], "cm/s")
        # g[("gas", "NG_Mask")] = (data_ngmask[i], "cm/s")
        i += 1


    ds = yt.load_amr_grids(grid_data, N_grids, length_unit=f"{Dom_size} * cm", geometry=("cartesian", ("z","y","x")), sim_time=sim_time)
    return ds

# %%
files = list(wr140.evolution[0:5])

# %%
from multiprocessing import Pool

list = [[0,1],[2,3],[4,]]

with Pool(processes=2) as pool:
    results = pool.map(sum, list)

    for result in results:
        print(result)
# Out:
# 1
# 5
# 4

# %%
from multiprocessing import Pool

with Pool(processes=2) as pool:
    ds = pool.imap_unordered(get_ds, files)

    for i in ds:
        print(i)
# Out:
# yt : [INFO     ] 2022-10-28 11:41:41,515 Parameters: current_time              = 0.0 s
# yt : [INFO     ] 2022-10-28 11:41:41,519 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:41:41,521 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:41:41,522 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:41:41,524 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-28 11:41:41,531 Parameters: current_time              = 44.62492578395574 s
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/pool.py", line 576, in _handle_results
#     task = get()
#   File "/usr/lib/python3.8/multiprocessing/connection.py", line 251, in recv
#     return _ForkingPickler.loads(buf.getbuffer())
#   File "/home/visitor_ap4/code/project/env/lib/python3.8/site-packages/yt/data_objects/static_output.py", line 1955, in _reconstruct_ds
#     ds = datasets.get_ds_hash(*args)
#   File "/home/visitor_ap4/code/project/env/lib/python3.8/site-packages/yt/utilities/parameter_file_storage.py", line 92, in get_ds_hash
#     return self._convert_ds(self._records[hash])
# KeyError: 'eab29d0dfb2720cf54652d7917328cfa'
# yt : [INFO     ] 2022-10-28 11:41:41,534 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:41:41,535 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:41:41,537 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:41:41,538 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-28 11:41:42,175 Parameters: current_time              = 81973.4933651852 s
# yt : [INFO     ] 2022-10-28 11:41:42,177 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:41:42,180 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:41:42,182 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:41:42,183 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-28 11:41:42,199 Parameters: current_time              = 283700.7975010876 s
# yt : [INFO     ] 2022-10-28 11:41:42,200 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:41:42,202 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:41:42,204 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:41:42,205 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-28 11:41:42,834 Parameters: current_time              = 429593.4423761949 s
# yt : [INFO     ] 2022-10-28 11:41:42,836 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:41:42,838 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:41:42,839 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:41:42,841 Parameters: cosmological_simulation   = 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.8/multiprocessing/pool.py:851, in IMapIterator.next(self, timeout)
#     850 try:
# --> 851     item = self._items.popleft()
#     852 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [52], line 6
#       4 ds = pool.imap_unordered(get_ds, files)
# ----> 6 for i in ds:
#       7     print(i)
#
# File /usr/lib/python3.8/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855     raise StopIteration from None
# --> 856 self._cond.wait(timeout)
#     857 try:
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     301 if timeout is None:
# --> 302     waiter.acquire()
#     303     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In [52], line 7
#       4 ds = pool.imap_unordered(get_ds, files)
#       6 for i in ds:
# ----> 7     print(i)
#
# File /usr/lib/python3.8/multiprocessing/pool.py:736, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     735 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 736     self.terminate()
#
# File /usr/lib/python3.8/multiprocessing/pool.py:654, in Pool.terminate(self)
#     652 util.debug('terminating pool')
#     653 self._state = TERMINATE
# --> 654 self._terminate()
#
# File /usr/lib/python3.8/multiprocessing/util.py:224, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     221 else:
#     222     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     223               self._callback, self._args, self._kwargs)
# --> 224     res = self._callback(*self._args, **self._kwargs)
#     225 self._weakref = self._callback = self._args = \
#     226                 self._kwargs = self._key = None
#     227 return res
#
# File /usr/lib/python3.8/multiprocessing/pool.py:695, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     692 cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     694 if (not result_handler.is_alive()) and (len(cache) != 0):
# --> 695     raise AssertionError(
#     696         "Cannot have cache with result_hander not alive")
#     698 result_handler._state = TERMINATE
#     699 change_notifier.put(None)
#
# AssertionError: Cannot have cache with result_hander not alive

# %%
# ds = get_ds(wr140.evolution[0])

# ts = yt.DatasetSeries([ds])
# Out:
# yt : [INFO     ] 2022-10-28 11:29:48,123 Parameters: current_time              = 0.0 s
# yt : [INFO     ] 2022-10-28 11:29:48,125 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-28 11:29:48,127 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-28 11:29:48,129 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-28 11:29:48,130 Parameters: cosmological_simulation   = 0
# StreamDataset: AMRGridData

# %%
def get_time_series():

    ds_list = []

    for i in range(100,121):
        data = ReadData(wr140.evolution[i])
        sim_time = data.sim_time()
        N_levels = data.nlevels()
        N_grids = data.ngrid()

        arr = np.array(wr140.evolution[i])

        data_den = ReadData(arr).get_3Darray("Density")['data']
        data_temp = ReadData(arr).get_3Darray("Temperature")['data']
        data_velx = ReadData(arr).get_3Darray("VelocityX")['data']
        data_vely = ReadData(arr).get_3Darray("VelocityY")['data']
        data_velz = ReadData(arr).get_3Darray("VelocityZ")['data']
        # data_ngmask = ReadData(arr).get_3Darray("NG_Mask")['data']

        grid_data = [dict(left_edge=[0.5-0.5**(n+1)]*len(N_grids), right_edge=[0.5+0.5**(n+1)]*len(N_grids), level=n, dimensions=N_grids) for n in range(N_levels)]

        i = 0
        for g in grid_data:
            g[("gas", "density")] = (data_den[i], "g/cm**3")
            g[("gas", "temperature")] = (data_temp[i], "K")
            g[("gas", "velocity_x")] = (data_velx[i], "cm/s")
            g[("gas", "velocity_y")] = (data_vely[i], "cm/s")
            g[("gas", "velocity_z")] = (data_velz[i], "cm/s")
            # g[("gas", "NG_Mask")] = (data_ngmask[i], "cm/s")
            i += 1


        ds = yt.load_amr_grids(grid_data, N_grids, length_unit="1e15 * cm", geometry=("cartesian", ("z","y","x")),sim_time=sim_time)
        ds_list.append(ds)  
        ds.close()
        data.close()
        grid_data.clear()
        

    ts = yt.DatasetSeries(ds_list)

    return ts

# %%
ts = get_time_series()
# Out:
# yt : [INFO     ] 2022-10-27 16:46:39,237 Parameters: current_time              = 24226745.988659706 s
# yt : [INFO     ] 2022-10-27 16:46:39,240 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:39,242 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:39,244 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:39,246 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:40,030 Parameters: current_time              = 24487589.970505852 s
# yt : [INFO     ] 2022-10-27 16:46:40,032 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:40,034 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:40,035 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:40,036 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:40,811 Parameters: current_time              = 24750095.98570558 s
# yt : [INFO     ] 2022-10-27 16:46:40,813 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:40,815 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:40,817 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:40,818 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:41,680 Parameters: current_time              = 25017810.148640662 s
# yt : [INFO     ] 2022-10-27 16:46:41,683 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:41,685 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:41,686 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:41,688 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:42,460 Parameters: current_time              = 25291837.346853174 s
# yt : [INFO     ] 2022-10-27 16:46:42,462 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:42,464 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:42,466 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:42,467 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:43,246 Parameters: current_time              = 25559313.1663085 s
# yt : [INFO     ] 2022-10-27 16:46:43,248 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:43,250 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:43,252 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:43,253 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:44,035 Parameters: current_time              = 25834406.06409706 s
# yt : [INFO     ] 2022-10-27 16:46:44,037 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:44,039 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:44,040 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:44,042 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:44,813 Parameters: current_time              = 26106195.92848559 s
# yt : [INFO     ] 2022-10-27 16:46:44,815 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:44,816 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:44,818 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:44,819 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:45,591 Parameters: current_time              = 26374495.793012872 s
# yt : [INFO     ] 2022-10-27 16:46:45,595 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:45,597 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:45,599 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:45,600 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:46,380 Parameters: current_time              = 26648786.431300856 s
# yt : [INFO     ] 2022-10-27 16:46:46,383 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:46,384 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:46,386 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:46,387 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:47,158 Parameters: current_time              = 26924590.705424067 s
# yt : [INFO     ] 2022-10-27 16:46:47,160 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:47,162 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:47,163 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:47,165 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:47,931 Parameters: current_time              = 27198100.70064046 s
# yt : [INFO     ] 2022-10-27 16:46:47,933 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:47,935 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:47,936 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:47,938 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:48,753 Parameters: current_time              = 27475252.054904208 s
# yt : [INFO     ] 2022-10-27 16:46:48,756 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:48,758 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:48,760 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:48,761 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:49,530 Parameters: current_time              = 27746485.728786007 s
# yt : [INFO     ] 2022-10-27 16:46:49,532 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:49,534 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:49,536 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:49,537 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:50,318 Parameters: current_time              = 28018625.25627378 s
# yt : [INFO     ] 2022-10-27 16:46:50,321 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:50,322 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:50,324 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:50,325 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:51,104 Parameters: current_time              = 28284474.8723017 s
# yt : [INFO     ] 2022-10-27 16:46:51,106 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:51,108 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:51,110 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:51,111 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:51,887 Parameters: current_time              = 28551476.872386348 s
# yt : [INFO     ] 2022-10-27 16:46:51,889 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:51,891 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:51,893 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:51,894 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:52,660 Parameters: current_time              = 28812626.109231878 s
# yt : [INFO     ] 2022-10-27 16:46:52,663 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:52,665 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:52,666 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:52,667 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:53,443 Parameters: current_time              = 29069992.6568325 s
# yt : [INFO     ] 2022-10-27 16:46:53,446 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:53,447 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:53,449 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:53,450 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:46:59,351 Parameters: current_time              = 29328661.56369047 s
# yt : [INFO     ] 2022-10-27 16:46:59,353 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:46:59,355 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:46:59,357 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:46:59,358 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-10-27 16:47:00,133 Parameters: current_time              = 29590660.007440284 s
# yt : [INFO     ] 2022-10-27 16:47:00,135 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-10-27 16:47:00,137 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-10-27 16:47:00,138 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-10-27 16:47:00,139 Parameters: cosmological_simulation   = 0

# %%
slc = yt.SlicePlot(ts[10], "z", "density", center=('c'),).annotate_grids()
slc.set_cmap("density", "viridis")

slc.zoom(2)
# slc.set_width((1.0, 'cm'))
# slc.annotate_velocity(normalize=True)
# slc.annotate_streamlines("velocity_x", "velocity_y", factor=10, density=2, color="white")
# slc.annotate_contour("temperature", levels=10, clim=(1e6, 1e8), plot_args={"colors":"white"})
# slc.annotate_cell_edges(line_width=0.0005, alpha=0.5)

slc.annotate_timestamp(corner="upper_left", redshift=False, draw_inset_box=True)
# slc.annotate_line_integral_convolution(("gas", "velocity_x"), ("gas", "velocity_y"), lim=(0.5, 0.75))
slc.show()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
sc = yt.create_scene(ts[10])
# identifying the source
source = sc[0]
source.set_field('density')
source.set_log(True)

# building transfer function
bounds = (1e-18, 1e-12)
tf = yt.ColorTransferFunction(x_bounds=np.log10(bounds))

# tf.add_gaussian(location=-14, width=0.07, height=[1,0,0,1])
# tf.add_gaussian(location=-14.8, width=0.07, height=[0.5,1,1,0.05])
tf.add_layers(5, w=0.005, colormap='viridis')
print(tf)

source.tfh.tf = tf
source.tfh.bounds = bounds
source.tfh.plot('/home/visitor_ap4/code/project/scripts/wr140_tf_density.png', profile_field='density')

sc.save('/home/visitor_ap4/code/project/scripts/wr140_density.png', sigma_clip=6.0)
sc.show()
# Out:
# yt : [INFO     ] 2022-10-27 19:31:50,887 Setting default field to ('gas', 'density')
# <Color Transfer Function Object>:
# x_bounds:[-18, -12] nbins:256 features:
# 	('gaussian', 'location(x):-18', 'width(x):0.005', 'height(y):(0.27, 0.031, 0.36, 0.001)')
# 	('gaussian', 'location(x):-16', 'width(x):0.005', 'height(y):(0.23, 0.33, 0.55, 0.0056)')
# 	('gaussian', 'location(x):-15', 'width(x):0.005', 'height(y):(0.13, 0.57, 0.55, 0.032)')
# 	('gaussian', 'location(x):-14', 'width(x):0.005', 'height(y):(0.34, 0.78, 0.4, 0.18)')
# 	('gaussian', 'location(x):-12', 'width(x):0.005', 'height(y):(0.95, 0.9, 0.11,   1)')
# yt : [WARNING  ] 2022-10-27 19:31:51,645 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:31:51,647 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:31:51,649 Creating volume
# yt : [INFO     ] 2022-10-27 19:31:52,945 Saving rendered image to /home/visitor_ap4/code/project/scripts/wr140_density.png
# <Scene Object>:
# Sources:
#     source_00: <Volume Source>:YTRegion (AMRGridData): , center=[5.e+14 5.e+14 5.e+14] cm, left_edge=[0. 0. 0.] cm, right_edge=[1.e+15 1.e+15 1.e+15] cm transfer_function:<Color Transfer Function Object>:
# x_bounds:[-18, -12] nbins:256 features:
# 	('gaussian', 'location(x):-18', 'width(x):0.005', 'height(y):(0.27, 0.031, 0.36, 0.001)')
# 	('gaussian', 'location(x):-16', 'width(x):0.005', 'height(y):(0.23, 0.33, 0.55, 0.0056)')
# 	('gaussian', 'location(x):-15', 'width(x):0.005', 'height(y):(0.13, 0.57, 0.55, 0.032)')
# 	('gaussian', 'location(x):-14', 'width(x):0.005', 'height(y):(0.34, 0.78, 0.4, 0.18)')
# 	('gaussian', 'location(x):-12', 'width(x):0.005', 'height(y):(0.95, 0.9, 0.11,   1)')
#
# Camera:
#     <Camera Object>:
# 	position:[1. 1. 1.] code_length
# 	focus:[0.5 0.5 0.5] code_length
# 	north_vector:[ 0.81649658 -0.40824829 -0.40824829]
# 	width:[1.5 1.5 1.5] code_length
# 	light:None
# 	resolution:(512, 512)
# Lens: <Lens Object>:
# 	lens_type:plane-parallel
# 	viewpoint:[-866025.33679714 -866025.33679714 -866025.33679714] code_length

# %%
# cam = sc.camera
# cam.get_focus()
# cam.zoom(6)

# cam.switch_orientation(normal_vector=[1, 0, 0], north_vector=[0, 1, 0])

# sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/frame_0.png', sigma_clip=6.0)

# for i in cam.iter_rotate(np.pi, 60):
#     sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/frame_{i+1}.png', sigma_clip=6.0, render=True)

# %%
for i in range(len(ts)):
    sc = yt.create_scene(ts[i])
    # identifying the source
    source = sc[0]
    source.set_field('density')
    source.set_log(True)

    # building transfer function
    bounds = (1e-18, 1e-12)
    tf = yt.ColorTransferFunction(x_bounds=np.log10(bounds))
    tf.add_layers(5, w=0.005, colormap='viridis')
    
    source.tfh.tf = tf
    source.tfh.bounds = bounds
    source.tfh.plot(f'/home/visitor_ap4/code/project/scripts/wr140_tf{i}_density.png', profile_field='density')
    
    cam = sc.camera
    cam.zoom(4)
    # cam.switch_orientation(normal_vector=[1, 0, 0], north_vector=[0, 1, 0])

    sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_{i}.png', sigma_clip=6.0)
    
    tf.clear()
# Out:
# yt : [INFO     ] 2022-10-27 19:58:43,974 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:44,830 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:44,832 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:44,835 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:46,539 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_0.png
# yt : [INFO     ] 2022-10-27 19:58:46,651 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:47,152 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:47,153 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:47,155 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:48,859 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_1.png
# yt : [INFO     ] 2022-10-27 19:58:48,986 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:49,507 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:49,508 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:49,512 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:51,216 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_2.png
# yt : [INFO     ] 2022-10-27 19:58:51,331 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:51,835 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:51,836 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:51,838 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:53,535 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_3.png
# yt : [INFO     ] 2022-10-27 19:58:53,701 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:54,186 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:54,187 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:54,189 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:55,867 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_4.png
# yt : [INFO     ] 2022-10-27 19:58:55,982 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:56,816 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:56,817 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:56,820 Creating volume
# yt : [INFO     ] 2022-10-27 19:58:58,512 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_5.png
# yt : [INFO     ] 2022-10-27 19:58:58,630 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:58:59,129 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:58:59,131 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:58:59,133 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:00,832 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_6.png
# yt : [INFO     ] 2022-10-27 19:59:00,991 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:01,486 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:01,487 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:01,490 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:03,212 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_7.png
# yt : [INFO     ] 2022-10-27 19:59:03,326 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:03,819 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:03,820 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:03,822 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:05,515 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_8.png
# yt : [INFO     ] 2022-10-27 19:59:05,629 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:06,119 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:06,121 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:06,123 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:07,828 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_9.png
# yt : [INFO     ] 2022-10-27 19:59:07,940 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:08,435 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:08,436 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:08,439 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:10,152 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_10.png
# yt : [INFO     ] 2022-10-27 19:59:10,350 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:11,193 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:11,194 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:11,196 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:12,919 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_11.png
# yt : [INFO     ] 2022-10-27 19:59:13,064 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:13,544 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:13,545 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:13,548 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:15,263 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_12.png
# yt : [INFO     ] 2022-10-27 19:59:15,379 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:15,857 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:15,858 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:15,860 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:17,572 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_13.png
# yt : [INFO     ] 2022-10-27 19:59:17,683 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:18,159 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:18,160 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:18,163 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:19,842 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_14.png
# yt : [INFO     ] 2022-10-27 19:59:19,949 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:20,423 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:20,424 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:20,426 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:22,121 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_15.png
# yt : [INFO     ] 2022-10-27 19:59:22,230 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:23,021 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:23,022 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:23,024 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:24,714 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_16.png
# yt : [INFO     ] 2022-10-27 19:59:24,824 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:25,308 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:25,310 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:25,312 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:27,011 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_17.png
# yt : [INFO     ] 2022-10-27 19:59:27,168 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:27,664 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:27,665 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:27,667 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:29,357 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_18.png
# yt : [INFO     ] 2022-10-27 19:59:29,471 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:29,966 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:29,967 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:29,969 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:31,659 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_19.png
# yt : [INFO     ] 2022-10-27 19:59:31,770 Setting default field to ('gas', 'density')
# yt : [WARNING  ] 2022-10-27 19:59:32,261 No previously rendered image found, rendering now.
# yt : [INFO     ] 2022-10-27 19:59:32,262 Rendering scene (Can take a while).
# yt : [INFO     ] 2022-10-27 19:59:32,265 Creating volume
# yt : [INFO     ] 2022-10-27 19:59:33,978 Saving rendered image to /home/visitor_ap4/code/project/scripts/yt_images/ts_stationary/frame_20.png

# %%
init_angle = 0

for i in range(len(ts)):
    sc = yt.create_scene(ts[i])

    # identifying the source
    source = sc[0]
    source.set_field('density')
    source.set_log(True)

    # building transfer function
    bounds = (1e-18, 1e-12)
    tf = yt.ColorTransferFunction(x_bounds=np.log10(bounds))
    tf.add_layers(5, w=0.005, colormap='viridis')
    
    source.tfh.tf = tf
    source.tfh.bounds = bounds


    cam = sc.camera
    # cam.zoom(4)
    # cam.switch_orientation(normal_vector=[1, 0, 0], north_vector=[0, 1, 0])
    # cam.rotate(init_angle)

    sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/{i}frame_0.png', sigma_clip=6.0)
    
    
    for j in cam.iter_zoom(1+(i*4/20), 5):
        sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/{i}frame_{j+1}.png', sigma_clip=6.0, render=True)

    # init_angle += np.pi/21

    # for j in cam.iter_rotate(init_angle, 4):
    #   sc.save(f'/home/visitor_ap4/code/project/scripts/yt_images/{i}frame_{j+1}.png', sigma_clip=6.0, render=True)


    
    tf.clear()
# Out:
# yt : [WARNING  ] 2022-10-27 20:37:24,367 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:37:26,161 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:37:32,607 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:37:34,431 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:37:41,006 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:37:42,810 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:37:49,187 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:37:50,935 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:37:57,224 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:37:58,938 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:05,083 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:06,755 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:13,151 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:14,830 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:21,203 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:22,949 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:29,241 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:30,977 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:37,102 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:38,827 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:45,089 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:46,850 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:38:53,198 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:38:54,912 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:01,372 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:03,137 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:09,451 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:11,144 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:17,554 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:19,277 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:25,611 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:27,293 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:33,626 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:35,302 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:41,537 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:43,256 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:49,524 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:51,324 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:39:57,623 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:39:59,386 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
# yt : [WARNING  ] 2022-10-27 20:40:05,809 No previously rendered image found, rendering now.
# yt : [WARNING  ] 2022-10-27 20:40:07,641 Previously rendered image exists, but rendering anyway. Supply 'render=False' to save previously rendered image directly.
