# %%
from silo_to_pickle import *

# %%
data_path = " /mnt/massive-stars/data/thomas_simulations/wr140-sims/covertex_start/orig_res/wr140-hydro-cool-n064/"
pickle_file = "/home/visitor_ap4/code/project/scripts/yt_folder/wr140_testnew2.pickle"

# %%
ts = yt_ts_from_pickle(pickle_file)
# Out:
# yt : [INFO     ] 2022-11-01 23:53:13,523 Parameters: current_time              = 0.0 s
# yt : [INFO     ] 2022-11-01 23:53:13,525 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-11-01 23:53:13,527 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-11-01 23:53:13,529 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-11-01 23:53:13,530 Parameters: cosmological_simulation   = 0
# yt : [INFO     ] 2022-11-01 23:53:13,582 Parameters: current_time              = 44.62492578395574 s
# yt : [INFO     ] 2022-11-01 23:53:13,584 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-11-01 23:53:13,586 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-11-01 23:53:13,588 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-11-01 23:53:13,589 Parameters: cosmological_simulation   = 0
# ...

# %%
ds = ts[0]

# %%
slc = yt.SlicePlot(ds, "z", "density")
slc.show()
# Out:
# yt : [INFO     ] 2022-11-01 23:53:52,566 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-01 23:53:52,568 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-01 23:53:52,569 xlim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-01 23:53:52,570 ylim = 0.000000 1.000000
# yt : [INFO     ] 2022-11-01 23:53:52,577 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
