# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
hdul = fits.open('/mnt/massive-stars/data/thomas_simulations/wr140-sims/covertex_start/red_z_res/wr140-hydro-l7n128/proj/wr140_hydro_cool_d3l7n128_XZ_img.00126976.fits')

hdul.info()
# Out:
# Filename: /mnt/massive-stars/data/thomas_simulations/wr140-sims/covertex_start/red_z_res/wr140-hydro-l7n128/proj/wr140_hydro_cool_d3l7n128_XZ_img.00126976.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  Proj_SurfaceMass    1 PrimaryHDU       9   (1440, 256)   float64
#   1  Proj_NeutralDens    1 ImageHDU         8   (1440, 256)   float64
#   2  Proj_IonizedDens    1 ImageHDU         8   (1440, 256)   float64
#   3  Proj_EmissionMeasure    1 ImageHDU         8   (1440, 256)   float64
#   4  Proj_XRAY_g00p1keV    1 ImageHDU         8   (1440, 256)   float64
#   5  Proj_XRAY_g00p2keV    1 ImageHDU         8   (1440, 256)   float64
#   6  Proj_XRAY_g00p3keV    1 ImageHDU         8   (1440, 256)   float64
#   7  Proj_XRAY_g00p5keV    1 ImageHDU         8   (1440, 256)   float64
#   8  Proj_XRAY_g01p0keV    1 ImageHDU         8   (1440, 256)   float64
#   9  Proj_XRAY_g02p0keV    1 ImageHDU         8   (1440, 256)   float64
#  10  Proj_XRAY_g05p0keV    1 ImageHDU         8   (1440, 256)   float64
#  11  Proj_XRAY_g10p0keV    1 ImageHDU         8   (1440, 256)   float64
#  12  Proj_Halpha    1 ImageHDU         8   (1440, 256)   float64
#  13  Proj_NII_ll6584    1 ImageHDU         8   (1440, 256)   float64
#  14  Proj_BREMS6GHZ    1 ImageHDU         8   (1440, 256)   float64

# %%
""" Display the image data with Matplotlib """

plt.figure()
plt.imshow(hdul[10].data, cmap='plasma')
plt.colorbar(location='top')
plt.show()
